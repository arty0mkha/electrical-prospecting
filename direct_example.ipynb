# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt 
from code import direct_problem as direct
# Out:
# direct_problem was imported

# %%
m=np.linspace(0,50,10000)
r=10
param=[100,20,50]
res=direct.potential_intergrand(m,r,param)

# %%
plt.plot(m,res)

# %%
r=np.logspace(-1,3,1000)
param=[100,20,50]
method='U'
resistance=direct.calculate_apparent_resistance(param,method,r)
# Out:
# c:\Users\ФИС\Documents\GitHub\electrical-prospecting\code\direct_problem.py:30: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   result.append( r_i*rho[0]*sp.integrate.quad(potential_intergrand, 0, np.inf, args=(r_i, param))[0])
# c:\Users\ФИС\Documents\GitHub\electrical-prospecting\code\direct_problem.py:30: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   result.append( r_i*rho[0]*sp.integrate.quad(potential_intergrand, 0, np.inf, args=(r_i, param))[0])
# ...

# %%
plt.loglog(r,resistance)
