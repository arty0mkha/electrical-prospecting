# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt 
from code import direct_problem as direct

# %%
m=np.linspace(0,1,10000)
r=10
param=[100,20,50]
res0=direct.potential_intergrand(m,r,param)
res1=direct.potential_intergrand(m,r*2,param)
res2=direct.potential_intergrand(m,r*4,param)

# %%
plt.plot(m,res0, label=f'r={r}')
plt.plot(m,res1, label=f'r={r*2}')
plt.plot(m,res2, label=f'r={r*4}')
plt.legend()
plt.title('Зависимость интегрируемой функции от r')
# Out:
# Text(0.5, 1.0, 'Зависимость интегрируемой функции от r')

# %%
r=np.logspace(-1,3,1000)
param=[100,20,50]
method='U'
resistance=direct.calculate_apparent_resistance(param,method,r,1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\ФИС\Documents\GitHub\electrical-prospecting\direct_example.ipynb Cell 4 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/%D0%A4%D0%98%D0%A1/Documents/GitHub/electrical-prospecting/direct_example.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> param=[100,20,50]
#       <a href='vscode-notebook-cell:/c%3A/Users/%D0%A4%D0%98%D0%A1/Documents/GitHub/electrical-prospecting/direct_example.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> method='U'
# ----> <a href='vscode-notebook-cell:/c%3A/Users/%D0%A4%D0%98%D0%A1/Documents/GitHub/electrical-prospecting/direct_example.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> resistance=direct.calculate_apparent_resistance(param,method,r,1)
#
# File c:\Users\ФИС\Documents\GitHub\electrical-prospecting\code\direct_problem.py:39, in calculate_apparent_resistance(param, method, r, col)
#      37   result = 0
#      38   for i in range(col):
# ---> 39     result += r*rho[0]*sp.integrate.quad(potential_intergrand, list_bessel0_zeros[i]/r, list_bessel0_zeros[i+1]/r, args=(r, param))[0]
#      40   result+=r*rho[0]*weber_lipchitz(r,0)
#      42 elif method == "E":
#
# File c:\Users\ФИС\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\integrate\_quadpack_py.py:438, in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst, complex_func)
#     435     args = (args,)
#     437 # check the limits of integration: \int_a^b, expect a < b
# --> 438 flip, a, b = b < a, min(a, b), max(a, b)
#     440 if complex_func:
#     441     def imfunc(x, *args):
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
plt.loglog(r,resistance)
