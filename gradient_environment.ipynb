# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
from code_folder.visualization_functions import geological_environment
from code_folder.direct_problem import calculate_apparent_resistance
# Out:
# visualization_functions were imported
# direct_problem was imported

# %%
rmin,rmax=0.1,10**4
r=np.logspace(np.log10(rmin),np.log10(rmax),25)

param=[]

for i in range(10,50):
    param.append(10+i)
    param.append(1)

for i in range(50):
    param.append(60-i)
    param.append(1)

param.append(50)
method='U'

# %%
rk_start=[]
for r_i in r:
    rk_start.append(calculate_apparent_resistance(param,method,r_i,num_of_zeros=10*int(1+r_i/200)))

# %%
plt.loglog(r,rk_start)

# %%
plt.imshow(geological_environment(param))
plt.colorbar()
